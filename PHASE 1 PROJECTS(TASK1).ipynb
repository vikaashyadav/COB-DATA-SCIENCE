# %%
import pandas as pd

# %%
import requests

# %%
api_url = "https://api.binance.com/api/v3/ticker/24hr"

response = requests.get(api_url)

# %%
if response.status_code == 200:
    #JSON data
    data = response.json()
    #Create a Pandas DataFrame from the parsed data:
    df = pd.DataFrame(data)
    #We save the DataFrame to a CSV file:
    df.to_csv('data.csv', index=False)
else:
    print(f"Failed to fetch data from the API")
    exit()

# %%
df
# Out:
#          symbol   priceChange priceChangePercent weightedAvgPrice  \
# 0        ETHBTC   -0.00033000             -0.534       0.06151706
# 1        LTCBTC   -0.00006900             -2.786       0.00243034
# 2        BNBBTC   -0.00001900             -0.234       0.00807807
# 3        NEOBTC   -0.00000540             -1.949       0.00027181
# 4       QTUMETH   -0.00001800             -1.332       0.00134595
# ...         ...           ...                ...              ...
# 2290   SOLFDUSD   -0.10000000             -0.523      18.93991200
# 2291    TOMOTRY   -0.70000000             -2.141      32.30354322
# 2292    UNFITRY  -10.90000000             -4.819     225.46887613
# 2293   XRPFDUSD   -0.00280000             -0.561       0.49583199
# 2294  DOGEFDUSD    0.00019000              0.305       0.06218034
#
#      prevClosePrice     lastPrice       lastQty      bidPrice         bidQty  \
# 0        0.06175000    0.06142000    0.01330000    0.06142000    29.59590000
# 1        0.00247600    0.00240800   14.52400000    0.00240700    35.32800000
# 2        0.00810800    0.00808900    7.18900000    0.00808800    25.17800000
# 3        0.00027670    0.00027170   27.40000000    0.00027150     7.19000000
# 4        0.00134600    0.00133300    5.00000000    0.00132500    46.20000000
# ...             ...           ...           ...           ...            ...
# 2290    19.07000000   19.03000000    0.47000000   19.00000000    10.53000000
# 2291    32.72000000   32.00000000  219.00000000   32.00000000  2909.00000000
# 2292   226.20000000  215.30000000  445.95000000  215.20000000    86.71000000
# 2293     0.49940000    0.49660000   18.00000000    0.49480000   202.00000000
# 2294     0.06237000    0.06244000  100.00000000    0.06242000  3205.00000000
#
#           askPrice  ...     openPrice     highPrice      lowPrice  \
# 0       0.06143000  ...    0.06175000    0.06180000    0.06127000
# 1       0.00240800  ...    0.00247700    0.00248200    0.00239500
# 2       0.00808900  ...    0.00810800    0.00811200    0.00804800
# 3       0.00027180  ...    0.00027710    0.00027720    0.00026700
# 4       0.00133200  ...    0.00135100    0.00137500    0.00132600
# ...            ...  ...           ...           ...           ...
# 2290   19.04000000  ...   19.13000000   19.24000000   18.79000000
# 2291   32.05000000  ...   32.70000000   32.92000000   31.80000000
# 2292  215.30000000  ...  226.20000000  230.20000000  215.10000000
# 2293    0.49600000  ...    0.49940000    0.50260000    0.49260000
# 2294    0.06269000  ...    0.06225000    0.06262000    0.06136000
#
#                volume        quoteVolume       openTime      closeTime  \
# 0       6604.05700000       406.26216345  1694848569395  1694934969395
# 1      52807.49900000       128.34023213  1694848557542  1694934957542
# 2      22302.94700000       180.16485696  1694848571914  1694934971914
# 3      13011.21000000         3.53657659  1694848528159  1694934928159
# 4       3017.40000000         4.06126690  1694848559665  1694934959665
# ...               ...                ...            ...            ...
# 2290    1313.71000000     24881.55180000  1694848568270  1694934968270
# 2291  170322.30000000   5502013.78000000  1694848563069  1694934963069
# 2292  120195.28000000  27100294.69800000  1694848568552  1694934968552
# 2293   38546.00000000     19112.33980000  1694848539737  1694934939737
# 2294   35949.00000000      2235.32095000  1694848569283  1694934969283
#
#         firstId     lastId  count
# 0     423057715  423073721  16007
# 1      93495875   93509209  13335
# 2     227105403  227129326  23924
# 3      45510025   45512564   2540
# 4       5401937    5402019     83
# ...         ...        ...    ...
# 2290       2063       2181    119
# 2291      58575      60206   1632
# 2292     169043     174635   5593
# 2293       3293       3428    136
# 2294       2463       2509     47
#
# [2295 rows x 21 columns]
